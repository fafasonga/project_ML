# %%
import scipy.io
import numpy as np
from pandas import read_csv
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.utils import np_utils
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Dense, Dropout, Activation, Flatten
from sklearn.metrics import confusion_matrix,roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(123)

# %%
data1 = scipy.io.loadmat('Dataset/glass.mat')['X']
data1_label = scipy.io.loadmat('Dataset/glass.mat')['y'].astype(int)
print(data1.shape[1])
data2 = scipy.io.loadmat('Dataset/mnist.mat')['X']
data2_label = scipy.io.loadmat('Dataset/mnist.mat')['y'].astype(int)
print(data2.shape[1])
data3 = scipy.io.loadmat('Dataset/satimage-2.mat')['X']
data3_label = scipy.io.loadmat('Dataset/satimage-2.mat')['y'].astype(int)
print(data3.shape[1])
data4 = scipy.io.loadmat('Dataset/speech.mat')['X']
data4_label = scipy.io.loadmat('Dataset/speech.mat')['y'].astype(int)
print(data4.shape[1])

data5 = scipy.io.loadmat('Dataset/ionosphere.mat')['X']
data5_label = scipy.io.loadmat('Dataset/ionosphere.mat')['y'].astype(int)
print(data5.shape[1])
# Out:
# 9
# 100
# 36
# 400
# 33

# %%
scaler = MinMaxScaler()
data1=scaler.fit_transform(data1)

# %%
results=[]
scores=[]
for i in range(0,10):
    X_train, X_test, y_train, y_test = train_test_split(data1, data1_label, test_size=0.8)
    model = Sequential()
    # Add an input layer 
    model.add(Dense(100, activation='relu', input_shape=(X_train.shape[1],)))
    # Add one hidden layer 
    model.add(Dense(100, activation='relu'))
    # Add an output layer 
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train,epochs=50, batch_size=1, verbose=0)
    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test, verbose=0)
    scores.append(score[1])
    # print(confusion_matrix(y_test, y_pred))
    print(roc_auc_score(y_test, y_pred))
    results.append(roc_auc_score(y_test, y_pred))
# Out:
# 0.9771341463414634
# 0.9991341991341991
# 0.9916167664670659
# 0.9878787878787879
# 0.9939393939393939
# 0.9645021645021645
# 0.9991341991341992
# 1.0
# 0.9923780487804877
# 0.997991967871486

# %%
plt.boxplot([results,scores],labels=['ROC-AUC','Accuracy'])
plt.show()

# %%
scaler = MinMaxScaler()
data2=scaler.fit_transform(data2)

# %%
result = []
scores=[]
for i in range(0,10):
    X_train, X_test, y_train, y_test = train_test_split(data2, data2_label, test_size=0.8)
    model = Sequential()

    # Add an input layer 
    model.add(Dense(100, activation='relu', input_shape=(X_train.shape[1],)))
    # Add one hidden layer 
    model.add(Dense(100, activation='relu'))
    # Add an output layer 
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train,epochs=20, batch_size=1, verbose=1)
    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test, verbose=0)
    scores.append(score[1])
    # print(confusion_matrix(y_test, y_pred))
    roc_result = roc_auc_score(y_test, y_pred)
    print(roc_result)
    result.append(roc_result*100)
# Out:
# Epoch 1/20
# 1520/1520 [==============================] - 13s 8ms/step - loss: 0.1235 - acc: 0.9539
# Epoch 2/20
# 1520/1520 [==============================] - 11s 8ms/step - loss: 0.0609 - acc: 0.9770
# Epoch 3/20
# 1520/1520 [==============================] - 8s 6ms/step - loss: 0.0406 - acc: 0.9842
# Epoch 4/20
# 1520/1520 [==============================] - 8s 5ms/step - loss: 0.0238 - acc: 0.9895
# Epoch 5/20
# 1520/1520 [==============================] - 10s 6ms/step - loss: 0.0131 - acc: 0.9961
# Epoch 6/20
# 1520/1520 [==============================] - 11s 7ms/step - loss: 0.
20
# 1520/1520 [==============================] - 11s 7ms/step - loss: 0.0010 - acc: 0.9993
# Epoch 17/20
# 1520/1520 [==============================] - 11s 7ms/step - loss: 0.0021 - acc: 0.9993
# Epoch 18/20
# 1520/1520 [==============================] - 10s 6ms/step - loss: 0.0101 - acc: 0.9987
# Epoch 19/20
# 1520/1520 [==============================] - 10s 6ms/step - loss: 0.0044 - acc: 0.9980
# Epoch 20/20
# 1520/1520 [==============================] - 10s 7ms/step - loss: 0.0139 - acc: 0.9967
# 0.990946942005403

# %%
plt.boxplot([results,scores],labels=['ROC-AUC','Accuracy'])
plt.show()

# %%
scaler = MinMaxScaler()
data3=scaler.fit_transform(data3)

# %%
result = []
scores=[]
for i in range(0,10):
    X_train, X_test, y_train, y_test = train_test_split(data3, data3_label, test_size=0.8)
    model = Sequential()

    # Add an input layer 
    model.add(Dense(20, activation='relu', input_shape=(X_train.shape[1],)))
    # Add one hidden layer 
    model.add(Dense(20, activation='relu'))
    # Add an output layer 
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train,epochs=20, batch_size=1, verbose=0)
    y_pred = model.predict(X_test)

    score = model.evaluate(X_test, y_test, verbose=0)
    scores.append(score[1])
    # print(confusion_matrix(y_test, y_pred))
    roc_result = roc_auc_score(y_test, y_pred)
    print(roc_result)
    result.append(roc_result)
# Out:
# 0.9755930724406189
# 0.9778147737082254
# 0.9794938917975569
# 0.9662103835244789
# 0.9828474872067916
# 0.9793883406916588
# 0.9946549254103211
# 0.9843007294341332
# 0.986694822533875
# 0.9702029008480622

# %%
plt.boxplot([results,scores],labels=['ROC-AUC','Accuracy'])
plt.show()

# %%
scaler = MinMaxScaler()
data4=scaler.fit_transform(data4)

# %%
result = []
scores=[]
for i in range(0,10):
    X_train, X_test, y_train, y_test = train_test_split(data4, data4_label, test_size=0.8)

    model = Sequential()

    # Add an input layer 
    model.add(Dense(50, activation='sigmoid', input_shape=(X_train.shape[1],)))
    # Add one hidden layer 
    model.add(Dense(50, activation='sigmoid'))
    # Add an output layer 
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train,epochs=20, batch_size=1, verbose=0)
    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test, verbose=0)
    scores.append(score[1])
    # print(confusion_matrix(y_test, y_pred))
    roc_result = roc_auc_score(y_test, y_pred)
    print(roc_result)
    result.append(roc_result)
# Out:
# 0.7086671958543636
# 0.75242497412901
# 0.7344923476637031
# 0.7997648609384594
# 0.7027165595347413
# 0.7587254395036194
# 0.6020229942828423
# 0.7525404343299559
# 0.7815411681914145
# 0.7022151855911447

# %%
plt.boxplot([result,scores],labels=['ROC-AUC','Accuracy'])
plt.show()

# %%
scaler = MinMaxScaler()
data5=scaler.fit_transform(data5)

# %%
result = []
scores=[]
for i in range(0,10):
    X_train, X_test, y_train, y_test = train_test_split(data5, data5_label, test_size=0.8)

    model = Sequential()

    # Add an input layer 
    model.add(Dense(50, activation='relu', input_shape=(X_train.shape[1],)))
    # Add one hidden layer 
    model.add(Dense(50, activation='relu'))
    # Add an output layer 
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train,epochs=30, batch_size=1, verbose=0)
    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test, verbose=0)
    scores.append(score[1])
    # print(confusion_matrix(y_test, y_pred))
    roc_result = roc_auc_score(y_test, y_pred)
    print(roc_result)
    result.append(roc_result)

# %%
plt.boxplot([result,scores],labels=['ROC-AUC','Accuracy'])
plt.show()
